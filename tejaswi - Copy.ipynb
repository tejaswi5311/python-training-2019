# %% [markdown]
# # file handling

# %%
f=open("teju.txt","w")
f.write("hello world")
f.close()

# %%
f=open("teju.txt","r")
data=f.read()
print(data)
# Out:
# hello world

# %%
f=open("teju.txt","a")
f.write("promize")
f.close()

# %%
import os
os.remove("teju.txt")

# %% [markdown]
# # create a folder
# # create some files with different names
# # insert random text and text should be different from file to file
# # size should be 512 bytes

# %%
import os
os.mkdir("school")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-3-946f2df4a2e5> in <module>
#       1 import os
# ----> 2 os.mkdir("school")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'school'

# %%
import os
f=open(os.path.join("school","first.txt"),"w")
f=open(os.path.join("school","second.txt"),"w")
f=open(os.path.join("school","third.txt"),"w")
f=open(os.path.join("school","fourth.txt"),"w")
f=open(os.path.join("school","fifth.txt"),"w")
f=open(os.path.join("school","sixth.txt"),"w")

# %%
for i in range(0,512):
    f=open("six.txt","w")
    f.write("a")
f.close()

# %%
for i in range(0,512):
    f=open("six.txt","r")
    print(f.read())
# Out:
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# a
# ...

# %%
import random
import string
def randomstring(stringlength):
    letters=string.ascii_lowercase
    b=''.join(random.choice(letters) for i in range(stringlength))
    return b


def file(stringlength):
    letters=string.ascii_lowercase
    a=''.join(random.choice(letters) for i in range(stringlength))
    return a

list=[]
for i in range(0,5):
    f=open(os.path.join("i",file(5)+"."".txt"),"w")
    f.write(randomstring(512))
f.close()

# %%
import os
os.mkdir("strength")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-10-ade500545d5f> in <module>
#       1 import os
# ----> 2 os.mkdir("strength")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'strength'

# %% [markdown]
# # swap the numbers
# # check the number 2digits or 3digits

# %%
a=int(input("enter a first value:"))
b=int(input("enter a second value:"))
a=a+b
b=a-b
a=a-b
print("a is:",a,"b is:",b)
# Out:
# enter a first value:10
# enter a second value:20
# a is: 20 b is: 10

# %%
n=int(input("enter a number:"))
if 9<n<99:
    print("two digit number:")
elif 99<n<999:
    print("it is a three digit:")
elif 999<n<9999:
    print("it is four digit:")
else:
    print("number is <=9 or>=9999")
# Out:
# enter a number:99
# number is <=9 or>=9999

# %%
n=int(input("enter a number:"))
if n>100 and n<999:
    print(n,"it is 3 digit num:")
else:
    print(n,"it is not a ")
# Out:
# enter a number:6
# 6 it is not a

# %% [markdown]
# # second largest number in list with out using max function

# %%
def secmax(a):
    li=[]
    for i in range(1,a+1):
        b=int(input("enter a number:"))
        li.append(b)
    return li[-2]
a=int(input("numbers is list:"))
secmax(a)
# Out:
# numbers is list:3
# enter a number:5
# enter a number:4
# enter a number:6
# 4

# %%
x=10
y=20
x=x-y
y=x+y
x=y-x
print(x,y)
# Out:
# 20 10

# %% [markdown]
# # we have the storage engiene in raptor
