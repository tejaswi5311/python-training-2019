# %%
import pandas as pd
import numpy as np
f1 = pd.read_csv(r'T:\Match.csv')
f1
# Out:
#      Match_SK  match_id                        Team1  \
# 0           0    335987  Royal Challengers Bangalore
# 1           1    335988              Kings XI Punjab
# 2           2    335989             Delhi Daredevils
# 3           3    335990               Mumbai Indians
# 4           4    335991        Kolkata Knight Riders
# 5           5    335992             Rajasthan Royals
# 6           6    335993              Deccan Chargers
# 7           7    335994          Chennai Super Kings
# 8           8    335995              Deccan Chargers
# 9           9    335996              Kings XI Punjab
# 10         10    335997  Royal Challengers Bangalore
# 11         11    335998          Chennai Super Kings
# 12         12    335999               Mumbai Indians
# 13         13    336000              Kings XI Punjab
# 14         14    336001  Royal Challengers Bangalore
# 15         15    336002        Kolkata Knight Riders
# 16         16    336003             Delhi Daredevils
# ...

# %%
#Print no. of matches won by each team based on year wise (each year as one column)
f2 = pd.read_csv(r'T:\Match.csv',usecols=['Season_Year'])
years = np.unique(f2.values)
years
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
#       dtype=int64)

# %%
f3 = pd.read_csv(r'T:\Match.csv',usecols=['Team1'])
teams = np.unique(f3.values)
teams
# Out:
# array(['Chennai Super Kings', 'Deccan Chargers', 'Delhi Daredevils',
#        'Gujarat Lions', 'Kings XI Punjab', 'Kochi Tuskers Kerala',
#        'Kolkata Knight Riders', 'Mumbai Indians', 'Pune Warriors',
#        'Rajasthan Royals', 'Rising Pune Supergiants',
#        'Royal Challengers Bangalore', 'Sunrisers Hyderabad'], dtype=object)

# %%
teams.shape
# Out:
# (13,)

# %%
df2 = pd.DataFrame()
df2['teams']= teams
df2.head()
# Out:
#                  teams
# 0  Chennai Super Kings
# 1      Deccan Chargers
# 2     Delhi Daredevils
# 3        Gujarat Lions
# 4      Kings XI Punjab

# %%
f4 = pd.read_csv(r'T:\Match.csv',usecols=['match_winner'])
f4.head()
# Out:
#                   match_winner
# 0        Kolkata Knight Riders
# 1          Chennai Super Kings
# 2             Delhi Daredevils
# 3  Royal Challengers Bangalore
# 4        Kolkata Knight Riders

# %%
f4.values
# Out:
# array([['Kolkata Knight Riders'],
#        ['Chennai Super Kings'],
#        ['Delhi Daredevils'],
#        ['Royal Challengers Bangalore'],
#        ['Kolkata Knight Riders'],
#        ['Rajasthan Royals'],
#        ['Delhi Daredevils'],
#        ['Chennai Super Kings'],
#        ['Rajasthan Royals'],
#        ['Kings XI Punjab'],
#        ['Rajasthan Royals'],
#        ['Chennai Super Kings'],
#        ['Deccan Chargers'],
#        ['Kings XI Punjab'],
#        ['Chennai Super Kings'],
#        ['Mumbai Indians'],
#        ['Delhi Daredevils'],
#        ['Kings XI Punjab'],
#        ['Rajasthan Royals'],
#        ['Delhi Daredevils'],
#        ['Royal Challengers Bangalore'],
#        ['Kings XI Punjab'],
#        ['Mumbai Indians'],
#        ['Rajasthan Royals'],
#        ['Kings XI Punjab'],
#        ['Deccan Chargers'],
#        ['Mumbai Indians'],
#        ['Chennai Super Kings'],
#        ['Kolkata Knight Riders'],
#        ['Rajasthan Royals'],
#        ['Mumbai Indians'],
# ...

# %%
f4.values[0]
# Out:
# array(['Kolkata Knight Riders'], dtype=object)

# %%
f2.shape
# Out:
# (637, 1)

# %%
f2 = years, f3= team1, f4 = match winner

# %%
for x in years:
    a=[]
    for y in teams:
        cnt=0
        for z in range(len(f4)):
            if y==f4.values[z] and f2.values[z]==x:
                cnt+=1
        a.append(cnt)
    df1[x] = a
print(df1)
# Out:
#                           teams  2008  2009  2010  2011  2012  2013  2014  \
# 0           Chennai Super Kings     9     8     9    11    10    12    10
# 1               Deccan Chargers     2     9     8     6     4     0     0
# 2              Delhi Daredevils     7    10     7     4    11     3     2
# 3                 Gujarat Lions     0     0     0     0     0     0     0
# 4               Kings XI Punjab    10     7     4     7     8     8    12
# 5          Kochi Tuskers Kerala     0     0     0     6     0     0     0
# 6         Kolkata Knight Riders     6     3     7     8    12     6    11
# 7                Mumbai Indians     7     5    11    10    10    13     7
# 8                 Pune Warriors     0     0     0     4     4     4     0
# 9              Rajasthan Royals    13     6     6     6     7    11     7
# 10      Rising Pune Supergiants     0     0     0     0     0     0     0
# 11  Royal Challengers Bangalore     4     9     8    10     8     9     5
# ...

# %%
x=[]
for i in f1.Team1:
    if i in x:
        pass
    else:
        x.append(i)
x
# Out:
# ['Royal Challengers Bangalore',
#  'Kings XI Punjab',
#  'Delhi Daredevils',
#  'Mumbai Indians',
#  'Kolkata Knight Riders',
#  'Rajasthan Royals',
#  'Deccan Chargers',
#  'Chennai Super Kings',
#  'Kochi Tuskers Kerala',
#  'Pune Warriors',
#  'Sunrisers Hyderabad',
#  'Gujarat Lions',
#  'Rising Pune Supergiants']

# %%
a=[]
b=[]
for i in teams:
    win=0
    loss=0
    for j in range(len(f1)):
        if i==f1.Toss_winner(j) and i==f1.match_winner(j):
            win+=1
        elif i==f1.Toss_winner(j) or i==df2.match_winner(j):
            loss+=1
            a.append(win)
            b.append(loss)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-56aa6933c903> in <module>
#       1 a=[]
#       2 b=[]
# ----> 3 for i in teams:
#       4     win=0
#       5     loss=0
#
# NameError: name 'teams' is not defined

# %%
df1.head()
# Out:
#                  teams  2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0  Chennai Super Kings     9     8     9    11    10    12    10    10     0
# 1      Deccan Chargers     2     9     8     6     4     0     0     0     0
# 2     Delhi Daredevils     7    10     7     4    11     3     2     5     7
# 3        Gujarat Lions     0     0     0     0     0     0     0     0     9
# 4      Kings XI Punjab    10     7     4     7     8     8    12     3     4
#
#    2017
# 0     0
# 1     0
# 2     6
# 3     4
# 4     7

# %%
#Print  ManOfMach count of each player in  Hyderabad stadium
f5 = pd.read_csv(r'T:\Match.csv',usecols=['ManOfMach'])
f5
# Out:
#             ManOfMach
# 0         BB McCullum
# 1          MEK Hussey
# 2         MF Maharoof
# 3          MV Boucher
# 4           DJ Hussey
# 5           SR Watson
# 6            V Sehwag
# 7           ML Hayden
# 8           YK Pathan
# 9       KC Sangakkara
# 10          SR Watson
# 11           JDP Oram
# 12       AC Gilchrist
# 13          SM Katich
# 14           MS Dhoni
# 15      ST Jayasuriya
# 16         GD McGrath
# 17           SE Marsh
# 18        SA Asnodkar
# 19           V Sehwag
# 20      R Vinay Kumar
# 21          IK Pathan
# 22         SM Pollock
# 23      Sohail Tanvir
# 24        S Sreesanth
# 25       AC Gilchrist
# 26            A Nehra
# 27           MS Dhoni
# 28         SC Ganguly
# 29          YK Pathan
# ..                ...
# 607            AJ Tye
# 608         G Gambhir
# 609       Rashid Khan
# 610       LH Ferguson
# 611         KH Pandya
# 612    Sandeep Sharma
# 613         DA Warner
# 614         RG Sharma
# 615         BA Stokes
# ...

# %%
man=f1[f1.City_Name=='Hyderabad']
man
l=[]
for i in man.ManOfMach:
    l.append(i)
#print(i)
m=[]
for j in l:
    if j in m:
        pass
    else:
        m.append(j)
n=[]
for i in m:
    a=l.count(i)
    n.append(a)
x=dict(zip(m,n))
x
# Out:
# {'V Sehwag': 2,
#  'YK Pathan': 2,
#  'SE Marsh': 1,
#  'R Vinay Kumar': 1,
#  'SC Ganguly': 1,
#  'DJ Bravo': 1,
#  'SK Raina': 2,
#  'SK Trivedi': 1,
#  'DW Steyn': 3,
#  'PC Valthaty': 1,
#  'SL Malinga': 1,
#  'MR Marsh': 1,
#  'DA Warner': 6,
#  'Mandeep Singh': 1,
#  'A Mishra': 2,
#  'GH Vihari': 2,
#  'I Sharma': 1,
#  'DJG Sammy': 1,
#  'PA Patel': 1,
#  'AT Rayudu': 1,
#  'WP Saha': 1,
#  'UT Yadav': 1,
#  'V Kohli': 1,
#  'MJ McClenaghan': 1,
#  'G Gambhir': 1,
#  'Mustafizur Rahman': 1,
#  'AB Dinda': 1,
#  'B Kumar': 1,
#  'CH Morris': 1}

# %%
#Print number of matches won and loss(as two columns). Consider as win when a team wins Toss  and Match . print for each and every team
